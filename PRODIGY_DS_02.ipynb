# %% [markdown]
# <a href="https://colab.research.google.com/github/maheswaran128/PRODIGY_DS_02/blob/main/PRODIGY_DS_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Python Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Read the csv file for titanic dataset

# %%
# Example: Load the Titanic dataset
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# #This command provides what are columns are present in the dataset

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# #This command is used to identify the NAN in dataset columns

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# ***In the dataset PassengerId,Name,Tickets are no significance on target variable
#
# ***The age has 177 and embarked has 2 and cabin has 687 missing values

# %% [markdown]
# #Data Reduction

# %%
df.drop(['PassengerId','Name','Ticket'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
df.nunique()
# Out:
# Survived      2
# Pclass        3
# Sex           2
# Age          88
# SibSp         7
# Parch         7
# Fare        248
# Cabin       147
# Embarked      3
# dtype: int64

# %%
df.describe(include='all')
# Out:
#           Survived      Pclass   Sex         Age       SibSp       Parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               Fare    Cabin Embarked
# count   891.000000      204      889
# unique         NaN      147        3
# top            NaN  B96 B98        S
# freq           NaN        4      644
# mean     32.204208      NaN      NaN
# std      49.693429      NaN      NaN
# min       0.000000      NaN      NaN
# 25%       7.910400      NaN      NaN
# 50%      14.454200      NaN      NaN
# 75%      31.000000      NaN      NaN
# max     512.329200      NaN      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Cabin     204 non-null    object
#  8   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %% [markdown]
# Splitting columns into Numerical and categorical columns

# %%
cat_cols=df.select_dtypes(include=['object']).columns
num_cols=df.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables are ",cat_cols)
print("Numerical Variables are ",num_cols)
# Out:
# Categorical Variables are  Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')
# Numerical Variables are  ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %% [markdown]
# #EDA Exploratory Data Analysis

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0           0       3    male  22.0      1      0   7.2500   NaN        S
# 1           1       1  female  38.0      1      0  71.2833   C85        C
# 2           1       3  female  26.0      0      0   7.9250   NaN        S
# 3           1       1  female  35.0      1      0  53.1000  C123        S
# 4           0       3    male  35.0      0      0   8.0500   NaN        S
# ..        ...     ...     ...   ...    ...    ...      ...   ...      ...
# 886         0       2    male  27.0      0      0  13.0000   NaN        S
# 887         1       1  female  19.0      0      0  30.0000   B42        S
# 888         0       3  female   NaN      1      2  23.4500   NaN        S
# 889         1       1    male  26.0      0      0  30.0000  C148        C
# 890         0       3    male  32.0      0      0   7.7500   NaN        Q
#
# [891 rows x 9 columns]

# %% [markdown]
# Univariate Analysis
#
#
#
# Categorical variables can be visualized using a Count plot, Bar Chart, Pie Plot, etc.
#
# Numerical Variables can be visualized using Histogram, Box Plot, Density Plot, etc.

# %%
for col in num_cols:
    print(col)
    plt.figure(figsize=(15,4))
    plt.subplot(1,2,1)
    sns.histplot(df[col],kde=True)
    plt.ylabel("Count")
    plt.subplot(1,2,2)
    sns.boxplot(df[col])
    plt.show()
# Out:
# PassengerId
# Survived
# Pclass
# Age
# SibSp
# Parch
# Fare

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Observations:
#
# Most people failed to survive in titanic
#
# Most people are travelling from 3rd class
#
# Most people age range vary from 20-40 and very few people are above 65
#
# Most people are travelling with no sibiling and spouse
#
# most people have no parent n children
#
# some outliers are present in fare

# %%
for col in cat_cols:
    print(col)
    plt.bar(df[col].value_counts().index, df[col].value_counts().values)
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()
# Out:
# Sex
# Cabin
# Embarked

# %% [markdown]
# Observations:
#
# People travelling in titanic are mostly male
#
# Most people embarked from southampton

# %% [markdown]
# BiVariate Analysis
#
# Countplot of each column against target variable

# %%
sns.pairplot(df)
plt.show()

# %%
for col in df.columns:
    if col != "Survived":
        plt.figure(figsize=(8,4))
        sns.countplot(x=col, hue="Survived", data=df)
        plt.xlabel(col)
        plt.ylabel("Count")
        plt.title(f"{col} vs Survived")
        plt.show()

# %% [markdown]
# Observations:
#
# Most 1st class people survived while 3rd class people died
#
# Most male died while most females survived
#
# Those having 1 sibiling or spouse has more chance of surviving
#
# Those having 1 parent or child has more chance of surviving
#
# Those who embarked from Cherbourg has great chance of survining

# %% [markdown]
# Multivariate Analysis

# %%
df1=df.select_dtypes(exclude=['object'])
plt.figure(figsize=(12, 7))
sns.heatmap(df1.corr(),annot=True)
plt.show()

# %% [markdown]
# Observations:
#
# Survival depends mostly on Pclass and Fare only
#
# 1st class has large Fare

# %% [markdown]
# #Feature Engineering

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0           0       3    male  22.0      1      0   7.2500   NaN        S
# 1           1       1  female  38.0      1      0  71.2833   C85        C
# 2           1       3  female  26.0      0      0   7.9250   NaN        S
# 3           1       1  female  35.0      1      0  53.1000  C123        S
# 4           0       3    male  35.0      0      0   8.0500   NaN        S
# ..        ...     ...     ...   ...    ...    ...      ...   ...      ...
# 886         0       2    male  27.0      0      0  13.0000   NaN        S
# 887         1       1  female  19.0      0      0  30.0000   B42        S
# 888         0       3  female   NaN      1      2  23.4500   NaN        S
# 889         1       1    male  26.0      0      0  30.0000  C148        C
# 890         0       3    male  32.0      0      0   7.7500   NaN        Q
#
# [891 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# #Handling Missing Values

# %%
round((df.isna().sum() / len(df))*100,2)
#Missing Values Percentage
# Out:
# Survived     0.00
# Pclass       0.00
# Sex          0.00
# Age         19.87
# SibSp        0.00
# Parch        0.00
# Fare         0.00
# Cabin       77.10
# Embarked     0.22
# dtype: float64

# %%
sns.distplot(df.Age)
# Out:
# <ipython-input-28-b2378c9d8a20>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Age)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
def impute_nan_mean(df,column,mean):
    df[column+'_mean'] = df[column].fillna(mean)
    return df

mean_val = df.Age.mean()
df_mean = impute_nan_mean(df,'Age',mean_val)

# %%
df_mean[df_mean.Age.isna()][['Age','Age_mean']]
# Out:
#      Age   Age_mean
# 5    NaN  29.699118
# 17   NaN  29.699118
# 19   NaN  29.699118
# 26   NaN  29.699118
# 28   NaN  29.699118
# ..   ...        ...
# 859  NaN  29.699118
# 863  NaN  29.699118
# 868  NaN  29.699118
# 878  NaN  29.699118
# 888  NaN  29.699118
#
# [177 rows x 2 columns]

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked  \
# 0           0       3    male  22.0      1      0   7.2500   NaN        S
# 1           1       1  female  38.0      1      0  71.2833   C85        C
# 2           1       3  female  26.0      0      0   7.9250   NaN        S
# 3           1       1  female  35.0      1      0  53.1000  C123        S
# 4           0       3    male  35.0      0      0   8.0500   NaN        S
# ..        ...     ...     ...   ...    ...    ...      ...   ...      ...
# 886         0       2    male  27.0      0      0  13.0000   NaN        S
# 887         1       1  female  19.0      0      0  30.0000   B42        S
# 888         0       3  female   NaN      1      2  23.4500   NaN        S
# 889         1       1    male  26.0      0      0  30.0000  C148        C
# 890         0       3    male  32.0      0      0   7.7500   NaN        Q
#
#       Age_mean
# 0    22.000000
# 1    38.000000
# 2    26.000000
# 3    35.000000
# 4    35.000000
# ..         ...
# 886  27.000000
# 887  19.000000
# 888  29.699118
# 889  26.000000
# 890  32.000000
#
# [891 rows x 10 columns]

# %%
def impute_nan_median(df,column,median):
    df[column+'_median'] = df[column].fillna(median)
    return df

median_val = df.Age.median()
df_med = impute_nan_median(df,'Age',median_val)

# %%
df_med[df_med.Age.isna()][['Age','Age_median']]
# Out:
#      Age  Age_median
# 5    NaN        28.0
# 17   NaN        28.0
# 19   NaN        28.0
# 26   NaN        28.0
# 28   NaN        28.0
# ..   ...         ...
# 859  NaN        28.0
# 863  NaN        28.0
# 868  NaN        28.0
# 878  NaN        28.0
# 888  NaN        28.0
#
# [177 rows x 2 columns]

# %%
def impute_nan_mode(df,column,mode):
    df[column+'_mode'] = df[column].fillna(mode)
    return df

mode_val = df.Age.mode()
df_mode = impute_nan_mode(df,'Age',mode_val)
df_mode[df_mode.Age.isna()][['Age','Age_mode']]
# Out:
#      Age  Age_mode
# 5    NaN       NaN
# 17   NaN       NaN
# 19   NaN       NaN
# 26   NaN       NaN
# 28   NaN       NaN
# ..   ...       ...
# 859  NaN       NaN
# 863  NaN       NaN
# 868  NaN       NaN
# 878  NaN       NaN
# 888  NaN       NaN
#
# [177 rows x 2 columns]

# %%
df[df.Age.notna()]['Age'].mode()[0]
# Out:
# 24.0

# %%
def impute_nan_mode(df,column,mode):
    df[column+'_mode'] = df[column].fillna(mode)
    return df

mode_val = df[df.Age.notna()]['Age'].mode()[0]    ## find mode of all the non missing values of Age column
df_mode = impute_nan_mode(df,'Age',mode_val)
df_mode[df_mode.Age.isna()][['Age','Age_mode']]
# Out:
#      Age  Age_mode
# 5    NaN      24.0
# 17   NaN      24.0
# 19   NaN      24.0
# 26   NaN      24.0
# 28   NaN      24.0
# ..   ...       ...
# 859  NaN      24.0
# 863  NaN      24.0
# 868  NaN      24.0
# 878  NaN      24.0
# 888  NaN      24.0
#
# [177 rows x 2 columns]

# %%
df.Embarked.isna().sum()

print(df['Embarked'].value_counts())
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
#### STEP 1: Find Mode Values
mode_cat_embarked = df.Embarked.mode()[0]

#### STEP 2: Fill Missing Values With Most Frequent Category
df['Embarked_mode'] = df['Embarked'].fillna(mode_cat_embarked)

#### Check For Results
df['Embarked_mode'].isna().sum()
# Out:
# 0

# %%
mode_cat_embarked
# Out:
# 'S'

# %%
df.isnull().sum()
# Out:
# Survived           0
# Pclass             0
# Sex                0
# Age              177
# SibSp              0
# Parch              0
# Fare               0
# Cabin            687
# Embarked           2
# Age_mean           0
# Age_median         0
# Age_mode           0
# Embarked_mode      0
# dtype: int64

# %%
### STEP 1: Generating Random Sample
sample = df.Age.sample().values[0]

### STEP 2: Filling nan values with random sample value
df['Age'+'_random_sample'] = df['Age'].fillna(sample)

df[df['Age'].isna()][['Age','Age_random_sample']]
# Out:
#      Age  Age_random_sample
# 5    NaN               28.0
# 17   NaN               28.0
# 19   NaN               28.0
# 26   NaN               28.0
# 28   NaN               28.0
# ..   ...                ...
# 859  NaN               28.0
# 863  NaN               28.0
# 868  NaN               28.0
# 878  NaN               28.0
# 888  NaN               28.0
#
# [177 rows x 2 columns]

# %%
### STEP 1: Generating Random Sample
sample = df.Age.sample().values[0]

### STEP 2: Filling nan values with random sample value
df['Age'+'_random_sample'] = df['Age'].fillna(sample)

df[df['Age'].isna()][['Age','Age_random_sample']]
# Out:
#      Age  Age_random_sample
# 5    NaN               38.0
# 17   NaN               38.0
# 19   NaN               38.0
# 26   NaN               38.0
# 28   NaN               38.0
# ..   ...                ...
# 859  NaN               38.0
# 863  NaN               38.0
# 868  NaN               38.0
# 878  NaN               38.0
# 888  NaN               38.0
#
# [177 rows x 2 columns]

# %%
sns.boxplot(x = 'Age',data=df)
# Out:
# <Axes: xlabel='Age'>

# %%
### STEP 1: Find Extreme Value
extreme = df.Age.mean() + 3*df.Age.std()

### STEP 2: Fill nan with extreme value
df['Age_end_distribution']  = df['Age'].fillna(extreme)

df
df[df['Age'].isna()][['Age','Age_end_distribution']]
# Out:
#      Age  Age_end_distribution
# 5    NaN              73.27861
# 17   NaN              73.27861
# 19   NaN              73.27861
# 26   NaN              73.27861
# 28   NaN              73.27861
# ..   ...                   ...
# 859  NaN              73.27861
# 863  NaN              73.27861
# 868  NaN              73.27861
# 878  NaN              73.27861
# 888  NaN              73.27861
#
# [177 rows x 2 columns]

# %%
### Filling Values using 0
df['Age_0'] = df['Age'].fillna(0)

### Filling Values using 100
df['Age_100'] = df['Age'].fillna(100)

df[df.Age.isna()][['Age','Age_0','Age_100']]
# Out:
#      Age  Age_0  Age_100
# 5    NaN    0.0    100.0
# 17   NaN    0.0    100.0
# 19   NaN    0.0    100.0
# 26   NaN    0.0    100.0
# 28   NaN    0.0    100.0
# ..   ...    ...      ...
# 859  NaN    0.0    100.0
# 863  NaN    0.0    100.0
# 868  NaN    0.0    100.0
# 878  NaN    0.0    100.0
# 888  NaN    0.0    100.0
#
# [177 rows x 3 columns]

# %%
df['Cabin_Missing'] = df['Cabin'].fillna('Missing')
df[df.Cabin.isna()][['Cabin','Cabin_Missing']]
# Out:
#     Cabin Cabin_Missing
# 0     NaN       Missing
# 2     NaN       Missing
# 4     NaN       Missing
# 5     NaN       Missing
# 7     NaN       Missing
# ..    ...           ...
# 884   NaN       Missing
# 885   NaN       Missing
# 886   NaN       Missing
# 888   NaN       Missing
# 890   NaN       Missing
#
# [687 rows x 2 columns]

# %%
df['Age_nan']=np.where(df['Age'].isnull(),1,0)
### STEP 1: Creating a new feature
df['Cabin_nan']=np.where(df['Cabin'].isnull(),1,0)
df.iloc[:5][['Cabin','Cabin_nan']]
# Out:
#   Cabin  Cabin_nan
# 0   NaN          1
# 1   C85          0
# 2   NaN          1
# 3  C123          0
# 4   NaN          1

# %%
df['Cabin'].mode()[0]
# Out:
# 'B96 B98'

# %%
df['Cabin'].fillna(df['Cabin'].mode()[0])
# Out:
# 0      B96 B98
# 1          C85
# 2      B96 B98
# 3         C123
# 4      B96 B98
#         ...
# 886    B96 B98
# 887        B42
# 888    B96 B98
# 889       C148
# 890    B96 B98
# Name: Cabin, Length: 891, dtype: object

# %%
df['Age_nan']=np.where(df['Age'].isnull(),1,0)
df[['Age','Age_nan']]
# Out:
#       Age  Age_nan
# 0    22.0        0
# 1    38.0        0
# 2    26.0        0
# 3    35.0        0
# 4    35.0        0
# ..    ...      ...
# 886  27.0        0
# 887  19.0        0
# 888   NaN        1
# 889  26.0        0
# 890  32.0        0
#
# [891 rows x 2 columns]

# %%
df[df.Age.isna()][['Age','Age_mean','Age_median', 'Age_mode', 'Age_random_sample','Age_end_distribution', 'Age_0', 'Age_100']]
# Out:
#      Age   Age_mean  Age_median  Age_mode  Age_random_sample  \
# 5    NaN  29.699118        28.0      24.0               38.0
# 17   NaN  29.699118        28.0      24.0               38.0
# 19   NaN  29.699118        28.0      24.0               38.0
# 26   NaN  29.699118        28.0      24.0               38.0
# 28   NaN  29.699118        28.0      24.0               38.0
# ..   ...        ...         ...       ...                ...
# 859  NaN  29.699118        28.0      24.0               38.0
# 863  NaN  29.699118        28.0      24.0               38.0
# 868  NaN  29.699118        28.0      24.0               38.0
# 878  NaN  29.699118        28.0      24.0               38.0
# 888  NaN  29.699118        28.0      24.0               38.0
#
#      Age_end_distribution  Age_0  Age_100
# 5                73.27861    0.0    100.0
# 17               73.27861    0.0    100.0
# 19               73.27861    0.0    100.0
# 26               73.27861    0.0    100.0
# 28               73.27861    0.0    100.0
# ..                    ...    ...      ...
# 859              73.27861    0.0    100.0
# 863              73.27861    0.0    100.0
# 868              73.27861    0.0    100.0
# 878              73.27861    0.0    100.0
# 888              73.27861    0.0    100.0
#
# [177 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# Survived                  0
# Pclass                    0
# Sex                       0
# Age                     177
# SibSp                     0
# Parch                     0
# Fare                      0
# Cabin                   687
# Embarked                  2
# Age_mean                  0
# Age_median                0
# Age_mode                  0
# Embarked_mode             0
# Age_random_sample         0
# Age_end_distribution      0
# Age_0                     0
# Age_100                   0
# Cabin_Missing             0
# Age_nan                   0
# Cabin_nan                 0
# dtype: int64

# %%
df.drop(["Age","Cabin","Embarked",'Age_median', 'Age_mode', 'Age_random_sample','Age_end_distribution', 'Age_0', 'Age_100',"Age_nan","Cabin_Missing"],axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass     Sex  SibSp  Parch     Fare   Age_mean Embarked_mode  \
# 0           0       3    male      1      0   7.2500  22.000000             S
# 1           1       1  female      1      0  71.2833  38.000000             C
# 2           1       3  female      0      0   7.9250  26.000000             S
# 3           1       1  female      1      0  53.1000  35.000000             S
# 4           0       3    male      0      0   8.0500  35.000000             S
# ..        ...     ...     ...    ...    ...      ...        ...           ...
# 886         0       2    male      0      0  13.0000  27.000000             S
# 887         1       1  female      0      0  30.0000  19.000000             S
# 888         0       3  female      1      2  23.4500  29.699118             S
# 889         1       1    male      0      0  30.0000  26.000000             C
# 890         0       3    male      0      0   7.7500  32.000000             Q
#
#      Cabin_nan
# 0            1
# 1            0
# 2            1
# 3            0
# 4            1
# ..         ...
# 886          1
# 887          0
# 888          1
# 889          0
# 890          1
#
# [891 rows x 9 columns]

# %%
df.rename(columns={'Age_mean': 'Age', 'Embarked_mode': 'Embarked', 'Cabin_nan': 'Cabin'}, inplace=True)
df
# Out:
#      Survived  Pclass     Sex  SibSp  Parch     Fare        Age Embarked  \
# 0           0       3    male      1      0   7.2500  22.000000        S
# 1           1       1  female      1      0  71.2833  38.000000        C
# 2           1       3  female      0      0   7.9250  26.000000        S
# 3           1       1  female      1      0  53.1000  35.000000        S
# 4           0       3    male      0      0   8.0500  35.000000        S
# ..        ...     ...     ...    ...    ...      ...        ...      ...
# 886         0       2    male      0      0  13.0000  27.000000        S
# 887         1       1  female      0      0  30.0000  19.000000        S
# 888         0       3  female      1      2  23.4500  29.699118        S
# 889         1       1    male      0      0  30.0000  26.000000        C
# 890         0       3    male      0      0   7.7500  32.000000        Q
#
#      Cabin
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1
# ..     ...
# 886      1
# 887      0
# 888      1
# 889      0
# 890      1
#
# [891 rows x 9 columns]

# %%
for col in num_cols:
    print(col)
    sns.boxplot(df[col])
    plt.show()
# Out:
# Survived
# Pclass
# Age
# SibSp
# Parch
# Fare

# %%
def removal_box_plot(df, column, threshold):
    sns.boxplot(df[column])
    plt.title(f'Original Box Plot of {column}')
    plt.show()

    removed_outliers = df[df[column] <= threshold]

    sns.boxplot(removed_outliers[column])
    plt.title(f'Box Plot without Outliers of {column}')
    plt.show()
    return removed_outliers
df1=removal_box_plot(df, 'Age', 53)
df1
# Out:
#      Survived  Pclass     Sex  SibSp  Parch     Fare        Age Embarked  \
# 0           0       3    male      1      0   7.2500  22.000000        S
# 1           1       1  female      1      0  71.2833  38.000000        C
# 2           1       3  female      0      0   7.9250  26.000000        S
# 3           1       1  female      1      0  53.1000  35.000000        S
# 4           0       3    male      0      0   8.0500  35.000000        S
# ..        ...     ...     ...    ...    ...      ...        ...      ...
# 886         0       2    male      0      0  13.0000  27.000000        S
# 887         1       1  female      0      0  30.0000  19.000000        S
# 888         0       3  female      1      2  23.4500  29.699118        S
# 889         1       1    male      0      0  30.0000  26.000000        C
# 890         0       3    male      0      0   7.7500  32.000000        Q
#
#      Cabin
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1
# ..     ...
# 886      1
# 887      0
# 888      1
# 889      0
# 890      1
#
# [841 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split
x=df.drop(["Survived"],axis=1)
y=df["Survived"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
x_train
# Out:
#      Pclass     Sex  SibSp  Parch      Fare        Age Embarked  Cabin
# 331       1    male      0      0   28.5000  45.500000        S      0
# 733       2    male      0      0   13.0000  23.000000        S      1
# 382       3    male      0      0    7.9250  32.000000        S      1
# 704       3    male      1      0    7.8542  26.000000        S      1
# 813       3  female      4      2   31.2750   6.000000        S      1
# ..      ...     ...    ...    ...       ...        ...      ...    ...
# 106       3  female      0      0    7.6500  21.000000        S      1
# 270       1    male      0      0   31.0000  29.699118        S      1
# 860       3    male      2      0   14.1083  41.000000        S      1
# 435       1  female      1      2  120.0000  14.000000        S      0
# 102       1    male      0      1   77.2875  21.000000        S      0
#
# [712 rows x 8 columns]

# %%
x_test
# Out:
#      Pclass     Sex  SibSp  Parch     Fare        Age Embarked  Cabin
# 709       3    male      1      1  15.2458  29.699118        C      1
# 439       2    male      0      0  10.5000  31.000000        S      1
# 840       3    male      0      0   7.9250  20.000000        S      1
# 720       2  female      0      1  33.0000   6.000000        S      1
# 39        3  female      1      0  11.2417  14.000000        C      1
# ..      ...     ...    ...    ...      ...        ...      ...    ...
# 433       3    male      0      0   7.1250  17.000000        S      1
# 773       3    male      0      0   7.2250  29.699118        C      1
# 25        3  female      1      5  31.3875  38.000000        S      1
# 84        2  female      0      0  10.5000  17.000000        S      1
# 10        3  female      1      1  16.7000   4.000000        S      0
#
# [179 rows x 8 columns]

# %%
y_train
# Out:
# 331    0
# 733    0
# 382    0
# 704    0
# 813    0
#       ..
# 106    1
# 270    0
# 860    0
# 435    1
# 102    0
# Name: Survived, Length: 712, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   SibSp     891 non-null    int64
#  4   Parch     891 non-null    int64
#  5   Fare      891 non-null    float64
#  6   Age       891 non-null    float64
#  7   Embarked  891 non-null    object
#  8   Cabin     891 non-null    int64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 62.8+ KB

# %%
df
# Out:
#      Survived  Pclass     Sex  SibSp  Parch     Fare        Age Embarked  \
# 0           0       3    male      1      0   7.2500  22.000000        S
# 1           1       1  female      1      0  71.2833  38.000000        C
# 2           1       3  female      0      0   7.9250  26.000000        S
# 3           1       1  female      1      0  53.1000  35.000000        S
# 4           0       3    male      0      0   8.0500  35.000000        S
# ..        ...     ...     ...    ...    ...      ...        ...      ...
# 886         0       2    male      0      0  13.0000  27.000000        S
# 887         1       1  female      0      0  30.0000  19.000000        S
# 888         0       3  female      1      2  23.4500  29.699118        S
# 889         1       1    male      0      0  30.0000  26.000000        C
# 890         0       3    male      0      0   7.7500  32.000000        Q
#
#      Cabin
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1
# ..     ...
# 886      1
# 887      0
# 888      1
# 889      0
# 890      1
#
# [891 rows x 9 columns]

# %%
df.describe()
# Out:
#          Survived      Pclass       SibSp       Parch        Fare         Age  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.523008    0.381594   32.204208   29.699118
# std      0.486592    0.836071    1.102743    0.806057   49.693429   13.002015
# min      0.000000    1.000000    0.000000    0.000000    0.000000    0.420000
# 25%      0.000000    2.000000    0.000000    0.000000    7.910400   22.000000
# 50%      0.000000    3.000000    0.000000    0.000000   14.454200   29.699118
# 75%      1.000000    3.000000    1.000000    0.000000   31.000000   35.000000
# max      1.000000    3.000000    8.000000    6.000000  512.329200   80.000000
#
#             Cabin
# count  891.000000
# mean     0.771044
# std      0.420397
# min      0.000000
# 25%      1.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000
